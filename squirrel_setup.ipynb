# %% [markdown]
# # 2018 Squirrel Census

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the dataset with `mongoimport --type csv -d squirrels_db -c squirrels --headerline  --drop 2018_Central_Park_Squirrel_Census_-_Squirrel_Data.csv`

# %%
# Import dependencies
from pymongo import MongoClient
import requests 
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
print(mongo.list_database_names())
# Out:
# ['admin', 'autosaurus', 'classDB', 'config', 'epa', 'fruits_db', 'local', 'met', 'squirrels_db', 'test', 'travel_db', 'uk_food']

# %%
# assign the squirrels_db database to a variable name
db = mongo['squirrels_db']

# %%
# review the collections in our new database
print(db.list_collection_names())
# Out:
# ['squirrels']

# %%
# assign the collection to a variable
squirrels = db['squirrels']

# %%
# review a document in the census_2018 collection
pprint(db.squirrels.find_one())
# Out:
# {'Above_Ground_Sighter_Measurement': '',
#  'Age': '',
#  'Approaches': 'FALSE',
#  'Chasing': 'FALSE',
#  'Climbing': 'FALSE',
#  'Color_notes': '',
#  'Combination_of_Primary_and_Highlight_Color': '+',
#  'Date': 10142018,
#  'Eating': 'FALSE',
#  'Foraging': 'FALSE',
#  'Hectare': '37F',
#  'Hectare_Squirrel_Number': 3,
#  'Highlight_Fur_Color': '',
#  'Indifferent': 'FALSE',
#  'Kuks': 'FALSE',
#  'Lat/Long': 'POINT (-73.9561344937861 40.7940823884086)',
#  'Location': '',
#  'Moans': 'FALSE',
#  'Other_Activities': '',
#  'Other_Interactions': '',
#  'Primary_Fur_Color': '',
#  'Quaas': 'FALSE',
#  'Running': 'FALSE',
#  'Runs_from': 'FALSE',
#  'Shift': 'PM',
#  'Specific_Location': '',
#  'Tail_flags': 'FALSE',
#  'Tail_twitches': 'FALSE',
#  'Unique_Squirrel_ID': '37F-PM-1014-03',
#  'X': -73.95613449,
#  'Y': 40.79408239,
#  '_id': ObjectId('642cca8711739165e7ee2b2f')}

# %% [markdown]
# ## Part 2: Review and update the database

# %%
# Total number of documents
print("Number of documents: ", squirrels.count_documents({}))
# Out:
# Number of documents:  3023

# %%
# Total number of documents
print("Number of documents: ", squirrels.count_documents({}))

# Total number of unique squirrels
unqiue_squirrels = squirrels.distinct("Unique_Squirrel_ID")
print("Number of unique squirrels in data set is: ",len(unqiue_squirrels))
# Out:
# Number of documents:  3023
# Number of unique squirrels in data set is:  3018

# %%
# Looking into the squirrels with duplicate 'Unique Squirrel ID's'
query = [{'$group': {'_id': "$Unique_Squirrel_ID", 'count': { '$sum': 1 }}}]

results = list(squirrels.aggregate(query))

# Save results to a dataframe
unique_df = pd.DataFrame(results)

# filter dataframe to only those that have a count greater than two
dups_df = unique_df.loc[unique_df['count'] >= 2]
dups_df
# Out:
#                  _id  count
# 102    1F-AM-1010-04      2
# 146   40B-AM-1019-06      2
# 767    7D-PM-1010-01      2
# 2400   4C-PM-1010-05      2
# 2917  37E-PM-1006-03      2

# %%
# Looking into data that have the same 'Unique Squirrel ID'

# Filter dataset to 5 unique squirrel ID's that have duplicates
query = {'Unique_Squirrel_ID' : {'$in': ["1F-AM-1010-04", "40B-AM-1019-06", "7D-PM-1010-01", "4C-PM-1010-05", "37E-PM-1006-03"]}}
results = list(squirrels.find(query))

# Save to a datafame
duplicate_squirrels_df = pd.DataFrame(results)

# Sort DataFrame on 'Unique Squirrel ID'
duplicate_squirrels = duplicate_squirrels_df.sort_values(by=['Unique_Squirrel_ID'])
duplicate_squirrels
# Out:
#                         _id          X          Y Unique_Squirrel_ID Hectare  \
# 7  642cca8711739165e7ee3514 -73.976620  40.766191      1F-AM-1010-04     01F
# 8  642cca8711739165e7ee3564 -73.976588  40.766095      1F-AM-1010-04     01F
# 0  642cca8711739165e7ee2b97 -73.957044  40.794851     37E-PM-1006-03     37E
# 6  642cca8711739165e7ee340e -73.956967  40.794879     37E-PM-1006-03     37E
# 2  642cca8711739165e7ee3133 -73.957711  40.798406     40B-AM-1019-06     40B
# 4  642cca8711739165e7ee33a6 -73.958236  40.798775     40B-AM-1019-06     40B
# 3  642cca8711739165e7ee3369 -73.977262  40.769282      4C-PM-1010-05     04C
# 9  642cca8711739165e7ee3677 -73.977165  40.769305      4C-PM-1010-05     04C
# 1  642cca8711739165e7ee2d34 -73.974945  40.772066      7D-PM-1010-01     07D
# 5  642cca8711739165e7ee33e9 -73.974852  40.771959      7D-PM-1010-01     07D
#
#   Shift      Date  Hectare_Squirrel_Number       Age Primary_Fur_Color  ...  \
# 7    AM  10102018                        4     Adult              Gray  ...
# 8    AM  10102018                        4     Adult              Gray  ...
# 0    PM  10062018                        3     Adult              Gray  ...
# 6    PM  10062018                        3     Adult              Gray  ...
# 2    AM  10192018                        6  Juvenile              Gray  ...
# 4    AM  10192018                        6  Juvenile              Gray  ...
# 3    PM  10102018                        5     Adult              Gray  ...
# 9    PM  10102018                        5     Adult              Gray  ...
# 1    PM  10102018                        1     Adult              Gray  ...
# 5    PM  10102018                        1     Adult              Gray  ...
#
#     Kuks  Quaas  Moans Tail_flags Tail_twitches Approaches Indifferent  \
# 7  FALSE  FALSE  FALSE      FALSE         FALSE      FALSE        TRUE
# 8  FALSE  FALSE  FALSE      FALSE         FALSE      FALSE        TRUE
# 0  FALSE  FALSE  FALSE      FALSE         FALSE      FALSE       FALSE
# 6  FALSE  FALSE  FALSE      FALSE         FALSE      FALSE       FALSE
# 2  FALSE  FALSE  FALSE      FALSE         FALSE      FALSE       FALSE
# 4  FALSE  FALSE  FALSE      FALSE         FALSE      FALSE       FALSE
# 3  FALSE  FALSE  FALSE      FALSE         FALSE      FALSE       FALSE
# 9  FALSE  FALSE  FALSE      FALSE         FALSE      FALSE       FALSE
# 1  FALSE  FALSE  FALSE      FALSE         FALSE      FALSE       FALSE
# 5  FALSE  FALSE  FALSE      FALSE         FALSE      FALSE       FALSE
#
#   Runs_from Other_Interactions                                      Lat/Long
# 7     FALSE                       POINT (-73.9766195697096 40.7661907261547)
# 8     FALSE                       POINT (-73.9765877920583 40.7660946071574)
# 0      TRUE                 me  POINT (-73.9570437717691 40.794850940803904)
# 6      TRUE                 me  POINT (-73.9569670900695 40.794879285681304)
# 2      TRUE                        POINT (-73.957710975899 40.7984055614047)
# 4      TRUE                       POINT (-73.9582363437135 40.7987752300505)
# 3     FALSE                       POINT (-73.9772624834791 40.7692821918543)
# 9     FALSE                       POINT (-73.9771646835311 40.7693049165084)
# 1     FALSE                       POINT (-73.9749446629706 40.7720659696067)
# 5     FALSE                       POINT (-73.9748522796455 40.7719586621003)
#
# [10 rows x 32 columns]

# %% [markdown]
# The data for each unqiue squirrel Id that has a duplicate is the same, except for the longitude and latitude values.  Which are slightly different between the squirrels with the same unique ID
# Given I'm unable to query the data, I will keep the duplicates in given their size is rather minimal and I do not have a clear reason to exlude them at this point.

# %% [markdown]
# <h5>Primary Fur Color

# %%
# Checking the primary fur colour field
query = [{'$group': {'_id': "$Primary_Fur_Color", 'count': { '$sum': 1 }}}]
results = list(squirrels.aggregate(query))
pprint(results)
# Out:
# [{'_id': 'Cinnamon', 'count': 392},
#  {'_id': '', 'count': 55},
#  {'_id': 'Gray', 'count': 2473},
#  {'_id': 'Black', 'count': 103}]

# %%
# Primary Fur Color - updating fields with "" to 'Unknown'
query = {"Primary_Fur_Color" : ""}
new_values = {"$set": {"Primary_Fur_Color": "Not_noted"}}
squirrels.update_many(query, new_values)

# Checking the update worked
query = [{'$group': {'_id': "$Primary_Fur_Color", 'count': { '$sum': 1 }}}]
results = list(squirrels.aggregate(query))
pprint(results)
# Out:
# [{'_id': 'Not_noted', 'count': 55},
#  {'_id': 'Black', 'count': 103},
#  {'_id': 'Gray', 'count': 2473},
#  {'_id': 'Cinnamon', 'count': 392}]

# %% [markdown]
# <h5> Age

# %%
# Checking the age field
query = [{'$group': {'_id': "$Age", 'count': { '$sum': 1 }}}]
results = list(squirrels.aggregate(query))
pprint(results)
# Out:
# [{'_id': '', 'count': 121},
#  {'_id': 'Adult', 'count': 2568},
#  {'_id': 'Juvenile', 'count': 330},
#  {'_id': '?', 'count': 4}]

# %%
# Age - updating fields with '' to 'Unknown'
query = {"Age" : ''}
new_values = {"$set": {"Age": "Not_noted"}}
squirrels.update_many(query, new_values)

# Age - updating fields with '?' to 'Unknown'
query = {"Age" : '?'}
new_values = {"$set": {"Age": "Not_noted"}}
squirrels.update_many(query, new_values)

# Checking the update worked
query = [{'$group': {'_id': "$Age", 'count': { '$sum': 1 }}}]
results = list(squirrels.aggregate(query))
pprint(results)
# Out:
# [{'_id': 'Not_noted', 'count': 125},
#  {'_id': 'Juvenile', 'count': 330},
#  {'_id': 'Adult', 'count': 2568}]

# %% [markdown]
# <h5> Shift field

# %%
# Checking the shift field
query = [{'$group': {'_id': "$Shift", 'count': { '$sum': 1 }}}]
results = list(squirrels.aggregate(query))
pprint(results)
# Out:
# [{'_id': 'PM', 'count': 1676}, {'_id': 'AM', 'count': 1347}]

# %% [markdown]
# <h5> Hectare

# %%
# Checking the Hectare field
query = [{'$group': {'_id': "$Hectare", 'count': { '$sum': 1 }}}]
results = list(squirrels.aggregate(query))
pprint(results)
# Out:
# [{'_id': '10F', 'count': 15},
#  {'_id': '08C', 'count': 10},
#  {'_id': '35G', 'count': 3},
#  {'_id': '39F', 'count': 9},
#  {'_id': '41G', 'count': 2},
#  {'_id': '09E', 'count': 7},
#  {'_id': '19E', 'count': 5},
#  {'_id': '22F', 'count': 15},
#  {'_id': '08F', 'count': 8},
#  {'_id': '22A', 'count': 9},
#  {'_id': '28C', 'count': 4},
#  {'_id': '09G', 'count': 10},
#  {'_id': '31C', 'count': 4},
#  {'_id': '22E', 'count': 2},
#  {'_id': '04E', 'count': 12},
#  {'_id': '33F', 'count': 8},
#  {'_id': '07C', 'count': 9},
#  {'_id': '13A', 'count': 9},
#  {'_id': '01H', 'count': 4},
#  {'_id': '30H', 'count': 4},
#  {'_id': '37D', 'count': 10},
#  {'_id': '32H', 'count': 4},
#  {'_id': '18I', 'count': 12},
#  {'_id': '14B', 'count': 11},
#  {'_id': '23A', 'count': 5},
#  {'_id': '14F', 'count': 15},
#  {'_id': '36H', 'count': 4},
#  {'_id': '36A', 'count': 11},
#  {'_id': '39D', 'count': 10},
#  {'_id': '35C', 'count': 14},
#  {'_id': '42A', 'count': 2},
#  {'_id': '42G', 'count': 6},
#  {'_id': '32E', 'count': 30},
#  {'_id': '08B', 'count': 18},
#  {'_id': '40E', 'count': 7},
#  {'_id': '39B', 'count': 7},
#  {'_id': '03H', 'count': 13},
#  {'_id': '23C', 'count': 5},
#  {'_id': '05F', 'count': 12},
#  {'_id': '33C', 'count': 6},
#  {'_id': '16A', 'count': 9},
#  {'_id': '09I', 'count': 16},
#  {'_id': '03C', 'count': 4},
#  {'_id': '35E', 'count': 11},
#  {'_id': '17D', 'count': 7},
#  {'_id': '01I', 'count': 4},
#  {'_id': '06C', 'count': 12},
#  {'_id': '07I', 'count': 8},
#  {'_id': '18C', 'count': 11},
#  {'_id': '15C', 'count': 8},
#  {'_id': '37F', 'count': 4},
#  {'_id': '13E', 'count': 24},
#  {'_id': '36I', 'count': 21},
#  {'_id': '16E', 'count': 20},
#  {'_id': '37A', 'count': 3},
#  {'_id': '31E', 'count': 10},
#  {'_id': '04A', 'count': 11},
#  {'_id': '02G', 'count': 7},
#  {'_id': '11I', 'count': 9},
#  {'_id': '31I', 'count': 4},
#  {'_id': '10G', 'count': 21},
#  {'_id': '40G', 'count': 8},
#  {'_id': '12F', 'count': 21},
#  {'_id': '17B', 'count': 6},
#  {'_id': '26I', 'count': 8},
#  {'_id': '36C', 'count': 10},
#  {'_id': '19G', 'count': 3},
#  {'_id': '42I', 'count': 3},
#  {'_id': '06F', 'count': 7},
#  {'_id': '30E', 'count': 4},
#  {'_id': '09H', 'count': 15},
#  {'_id': '07F', 'count': 20},
#  {'_id': '15D', 'count': 14},
#  {'_id': '25B', 'count': 2},
#  {'_id': '11A', 'count': 5},
#  {'_id': '31A', 'count': 9},
#  {'_id': '15I', 'count': 13},
#  {'_id': '33B', 'count': 18},
#  {'_id': '01C', 'count': 12},
#  {'_id': '09D', 'count': 4},
#  {'_id': '28I', 'count': 2},
#  {'_id': '17H', 'count': 2},
#  {'_id': '06D', 'count': 10},
#  {'_id': '16D', 'count': 19},
#  {'_id': '07H', 'count': 26},
#  {'_id': '11D', 'count': 13},
#  {'_id': '12E', 'count': 14},
#  {'_id': '18F', 'count': 4},
#  {'_id': '06G', 'count': 10},
#  {'_id': '11F', 'count': 6},
#  {'_id': '06E', 'count': 6},
#  {'_id': '30F', 'count': 1},
#  {'_id': '15F', 'count': 17},
#  {'_id': '35A', 'count': 20},
#  {'_id': '40C', 'count': 15},
#  {'_id': '39E', 'count': 7},
#  {'_id': '21D', 'count': 12},
#  {'_id': '02B', 'count': 17},
#  {'_id': '04G', 'count': 6},
#  {'_id': '02H', 'count': 6}]

# %% [markdown]
# <h5> Location

# %%
# Checking the Location field
query = [{'$group': {'_id': "$Location", 'count': { '$sum': 1 }}}]
results = list(squirrels.aggregate(query))
pprint(results)
# Out:
# [{'_id': '', 'count': 64},
#  {'_id': 'Above Ground', 'count': 843},
#  {'_id': 'Ground Plane', 'count': 2116}]

# %%
# Location - updating fields with '' to 'Unknown'
query = {"Location" : ''}
new_values = {"$set": {"Location": "Not_noted"}}
squirrels.update_many(query, new_values)

# Checking the update worked
query = [{'$group': {'_id': "$Location", 'count': { '$sum': 1 }}}]
results = list(squirrels.aggregate(query))
pprint(results)
# Out:
# [{'_id': 'Above Ground', 'count': 843},
#  {'_id': 'Ground Plane', 'count': 2116},
#  {'_id': 'Not_noted', 'count': 64}]

# %% [markdown]
# <h5> Combinatin of Primary and Highlight Color

# %%
# Checking the combination of primary and highligh color field
query = [{'$group': {'_id': "$Combination_of_Primary_and_Highlight_Color", 'count': { '$sum': 1 }}}]
results = list(squirrels.aggregate(query))
pprint(results)
# Out:
# [{'_id': 'Cinnamon+White', 'count': 94},
#  {'_id': 'Black+White', 'count': 2},
#  {'_id': 'Gray+Cinnamon', 'count': 752},
#  {'_id': 'Gray+Cinnamon, White', 'count': 265},
#  {'_id': 'Gray+Black, White', 'count': 7},
#  {'_id': 'Black+Cinnamon, White', 'count': 3},
#  {'_id': 'Gray+Black', 'count': 24},
#  {'_id': '+', 'count': 55},
#  {'_id': 'Cinnamon+Black, White', 'count': 3},
#  {'_id': 'Black+Gray, White', 'count': 1},
#  {'_id': 'Cinnamon+Gray', 'count': 162},
#  {'_id': 'Gray+', 'count': 895},
#  {'_id': 'Black+Cinnamon', 'count': 15},
#  {'_id': 'Cinnamon+', 'count': 62},
#  {'_id': 'Black+', 'count': 74},
#  {'_id': 'Gray+Black, Cinnamon, White', 'count': 32},
#  {'_id': 'Cinnamon+Gray, White', 'count': 58},
#  {'_id': 'Gray+White', 'count': 489},
#  {'_id': 'Gray+Black, Cinnamon', 'count': 9},
#  {'_id': 'Cinnamon+Black', 'count': 10},
#  {'_id': 'Black+Gray', 'count': 8},
#  {'_id': 'Cinnamon+Gray, Black', 'count': 3}]

# %% [markdown]
# <h5> Highlight Fur Color

# %%
query = [{'$group': {'_id': "$Highlight_Fur_Color", 'count': { '$sum': 1 }}}]
results = list(squirrels.aggregate(query))
pprint(results)
# Out:
# [{'_id': 'Gray, White', 'count': 59},
#  {'_id': 'Cinnamon', 'count': 767},
#  {'_id': 'White', 'count': 585},
#  {'_id': 'Cinnamon, White', 'count': 268},
#  {'_id': 'Gray, Black', 'count': 3},
#  {'_id': 'Black', 'count': 34},
#  {'_id': 'Black, Cinnamon, White', 'count': 32},
#  {'_id': '', 'count': 1086},
#  {'_id': 'Black, Cinnamon', 'count': 9},
#  {'_id': 'Black, White', 'count': 10},
#  {'_id': 'Gray', 'count': 170}]

# %%
# highlight fur color - updating fields with '' to 'not_noted'
query = {"Highlight_Fur_Color" : ''}
new_values = {"$set": {"Highlight_Fur_Color": "Not_noted"}}
squirrels.update_many(query, new_values)

# Checking the update worked
query = [{'$group': {'_id': "$Highlight_Fur_Color", 'count': { '$sum': 1 }}}]
results = list(squirrels.aggregate(query))
pprint(results)
# Out:
# [{'_id': 'Black, Cinnamon', 'count': 9},
#  {'_id': 'Black', 'count': 34},
#  {'_id': 'White', 'count': 585},
#  {'_id': 'Gray, White', 'count': 59},
#  {'_id': 'Cinnamon, White', 'count': 268},
#  {'_id': 'Gray', 'count': 170},
#  {'_id': 'Cinnamon', 'count': 767},
#  {'_id': 'Gray, Black', 'count': 3},
#  {'_id': 'Black, White', 'count': 10},
#  {'_id': 'Not_noted', 'count': 1086},
#  {'_id': 'Black, Cinnamon, White', 'count': 32}]

# %% [markdown]
# <h5> Specific Location

# %%
query = [{'$group': {'_id': "$Specific_Location", 'count': { '$sum': 1 }}}]
results = list(squirrels.aggregate(query))
pprint(results)
# Out:
# [{'_id': 'on fallen tree', 'count': 1},
#  {'_id': 'High in a tree', 'count': 1},
#  {'_id': 'Different tree', 'count': 1},
#  {'_id': 'in trees, then to ground', 'count': 1},
#  {'_id': 'Climbing up rocks', 'count': 1},
#  {'_id': 'by water', 'count': 1},
#  {'_id': 'Tree', 'count': 7},
#  {'_id': 'On rocks', 'count': 1},
#  {'_id': 'on hill', 'count': 1},
#  {'_id': 'fence', 'count': 5},
#  {'_id': 'Running across fence between statue & swings', 'count': 1},
#  {'_id': 'on path', 'count': 1},
#  {'_id': 'Fence pole', 'count': 1},
#  {'_id': 'Dog chased up tree', 'count': 1},
#  {'_id': 'Low tree', 'count': 1},
#  {'_id': 'bench', 'count': 1},
#  {'_id': 'Running from one tree to the other', 'count': 1},
#  {'_id': 'Oak tree near rock outcropping', 'count': 1},
#  {'_id': 'Behind fence, tree trunk', 'count': 1},
#  {'_id': 'on branch of dead tree', 'count': 1},
#  {'_id': 'Tree & ground', 'count': 2},
#  {'_id': 'perched on small fence', 'count': 1},
#  {'_id': 'on a log', 'count': 1},
#  {'_id': 'unsure, just heard kuks', 'count': 1},
#  {'_id': 'behind playground benches', 'count': 1},
#  {'_id': 'On rock', 'count': 1},
#  {'_id': 'running across overpass', 'count': 1},
#  {'_id': 'Right behind fence of the conservatory', 'count': 1},
#  {'_id': 'edge of landscape', 'count': 1},
#  {'_id': 'Behind fence, grass', 'count': 3},
#  {'_id': 'playing very high in tree w/ #7', 'count': 1},
#  {'_id': 'on fallen log', 'count': 1},
#  {'_id': 'on tree trunk', 'count': 2},
#  {'_id': 'Also way up', 'count': 1},
#  {'_id': 'End of tree limb foraging', 'count': 1},
#  {'_id': 'grass', 'count': 2},
#  {'_id': 'climbing trees', 'count': 1},
#  {'_id': 'In the Woods/Brush', 'count': 1},
#  {'_id': 'chased squirrel #2 away', 'count': 1},
#  {'_id': 'on fence', 'count': 8},
#  {'_id': 'road', 'count': 1},
#  {'_id': 'by large tree in sectioned off area', 'count': 1},
#  {'_id': 'lawn @ edge of landscaped area', 'count': 1},
#  {'_id': 'Under Tupelo Tree', 'count': 1},
#  {'_id': 'near a brush', 'count': 1},
#  {'_id': 'near base of small tree', 'count': 2},
#  {'_id': 'landscaped area', 'count': 1},
#  {'_id': 'Near Summerstage', 'count': 1},
#  {'_id': 'on tree', 'count': 3},
#  {'_id': 'On top of park lamp', 'count': 1},
#  {'_id': 'Rock a', 'count': 1},
#  {'_id': 'climbed the fence & posed for a picture', 'count': 1},
#  {'_id': 'Across Transverse', 'count': 1},
#  {'_id': 'Sitting on back of bench with food hanging from mouth', 'count': 1},
#  {'_id': 'Base of tree', 'count': 1},
#  {'_id': 'over a log across stream', 'count': 1},
#  {'_id': 'in hole in tree', 'count': 1},
#  {'_id': 'on rocks/bushy rocks', 'count': 1},
#  {'_id': 'Climbed fence', 'count': 1},
#  {'_id': 'on log', 'count': 1},
#  {'_id': 'Across Arbor path into hill w/ bushes', 'count': 1},
#  {'_id': 'in bush', 'count': 1},
#  {'_id': 'under bench', 'count': 1},
#  {'_id': 'foot of tree', 'count': 2},
#  {'_id': 'on bar', 'count': 1},
#  {'_id': 'in tree', 'count': 32},
#  {'_id': 'shelter in hole in tree', 'count': 2},
#  {'_id': 'BIG TREE', 'count': 2},
#  {'_id': 'in grass', 'count': 3},
#  {'_id': 'CROSS BRIDLE - INTO TREE TO AVOID DOGGO', 'count': 1},
#  {'_id': 'low branch', 'count': 1},
#  {'_id': 'building nest', 'count': 1},
#  {'_id': 'just to right when enter sanctuary', 'count': 1},
#  {'_id': 'tree trunk', 'count': 2},
#  {'_id': 'by bike racks at Tavern on the Green', 'count': 1},
#  {'_id': 'Bench', 'count': 1},
#  {'_id': 'outside fenced hectare', 'count': 2},
#  {'_id': 'rocks', 'count': 2},
#  {'_id': 'small open area but w/ 7 large oak trees', 'count': 3},
#  {'_id': 'Under bench', 'count': 1},
#  {'_id': 'way up a tree!', 'count': 1},
#  {'_id': '5, 6, 7 all at same tree trunk base', 'count': 3},
#  {'_id': 'on rock', 'count': 3},
#  {'_id': 'near fence', 'count': 2},
#  {'_id': 'on tennis club house roof', 'count': 1},
#  {'_id': 'grass field', 'count': 1},
#  {'_id': 'stay on side of trunk', 'count': 1},
#  {'_id': 'above my head in tree', 'count': 1},
#  {'_id': 'Crossing path to tree', 'count': 1},
#  {'_id': 'up a tree', 'count': 2},
#  {'_id': 'across the lawn and climb up a small tree', 'count': 1},
#  {'_id': 'in middle of path', 'count': 1},
#  {'_id': 'climbed a fence', 'count': 1},
#  {'_id': 'on the lawn East of the fountain', 'count': 1},
#  {'_id': 'base of tree', 'count': 2},
#  {'_id': 'CLIMBED THE TREE', 'count': 1},
#  {'_id': 'oak tree at end of ramp from Chess House', 'count': 1},
#  {'_id': 'by tree', 'count': 1},
#  {'_id': 'bushes', 'count': 1},
#  {'_id': 'Climbing tree', 'count': 1},
#  {'_id': 'THICK UNDERGROWTH', 'count': 3},
#  {'_id': 'on/in log', 'count': 1},
#  {'_id': 'in b/w trees', 'count': 1},
#  {'_id': 'under a tree', 'count': 4},
#  {'_id': 'tree', 'count': 43},
#  {'_id': 'behind fence, safe', 'count': 1},
#  {'_id': 'Grass', 'count': 2},
#  {'_id': 'In the weeds by the pool', 'count': 1},
#  {'_id': 'close to tall tree & light post', 'count': 2},
#  {'_id': 'ran up tree', 'count': 1},
#  {'_id': 'on the path', 'count': 1},
#  {'_id': 'tree near large rock on Bridle Path', 'count': 1},
#  {'_id': 'playground', 'count': 1},
#  {'_id': 'middle of grass', 'count': 1},
#  {'_id': 'base of tree with ~ 30 small birds all eating', 'count': 1},
#  {'_id': 'Fence', 'count': 1},
#  {'_id': 'Under the tree', 'count': 2},
#  {'_id': 'up tree', 'count': 1},
#  {'_id': 'On a rock', 'count': 1},
#  {'_id': 'Tree to ground', 'count': 1},
#  {'_id': 'in the European Beech', 'count': 1},
#  {'_id': 'Ground then tree to eat', 'count': 1},
#  {'_id': 'Near rock', 'count': 2},
#  {'_id': 'edge of park @ 98th (north)', 'count': 1},
#  {'_id': 'Ran up tree', 'count': 1},
#  {'_id': 'lower branch of tree', 'count': 1},
#  {'_id': 'on tree knob', 'count': 1},
#  {'_id': 'Clearing near bike path (bikes active)', 'count': 3},
#  {'_id': 'In small tree by water', 'count': 1},
#  {'_id': 'Bushes', 'count': 1},
#  {'_id': 'by carousel', 'count': 1},
#  {'_id': 'rocky outcrop', 'count': 1},
#  {'_id': 'in grass by light post', 'count': 1},
#  {'_id': 'Rocky area', 'count': 1},
#  {'_id': 'went up tree', 'count': 1},
#  {'_id': 'chain link fence', 'count': 1},
#  {'_id': 'Jumped onto path & then back into brush', 'count': 1},
#  {'_id': 'trellis', 'count': 1},
#  {'_id': 'thin branch of tree', 'count': 1},
#  {'_id': 'Open ground', 'count': 1},
#  {'_id': 'running up and down', 'count': 1},
#  {'_id': 'willow oak tree', 'count': 2},
#  {'_id': 'climbing in bush', 'count': 1},
#  {'_id': 'Same tree (as #6)', 'count': 1},
#  {'_id': 'Ground then up tree', 'count': 1},
#  {'_id': 'on a bench', 'count': 1},
#  {'_id': 'walking along path', 'count': 1},
#  {'_id': 'on tree trunk (descending from height of ~10 ft)', 'count': 1},
#  {'_id': 'trash can', 'count': 1},
#  {'_id': 'under a parked car', 'count': 1},
#  {'_id': 'rubbing belly on ground', 'count': 1},
#  {'_id': 'edge of park at 108th West', 'count': 1},
#  {'_id': 'near Strawberry Fields', 'count': 1},
#  {'_id': 'playing very high in tree w/ #8', 'count': 1},
#  {'_id': 'underneath a tree', 'count': 1},
#  {'_id': 'trail', 'count': 1},
#  {'_id': 'in tall planetree', 'count': 1},
#  {'_id': '"FIELD"', 'count': 2},
#  {'_id': 'in bushes, then ran across path', 'count': 1},
#  {'_id': 'another tree', 'count': 1},
#  {'_id': 'Running across wide street', 'count': 1},
#  {'_id': 'on a tree', 'count': 3},
#  {'_id': 'Arbor path & hill w/ bushes', 'count': 1},
#  {'_id': 'lawn', 'count': 3},
#  {'_id': 'At rock', 'count': 1},
#  {'_id': 'Woods', 'count': 3},
#  {'_id': '(white oak)', 'count': 1},
#  {'_id': 'By large tree chasing #1', 'count': 1},
#  {'_id': 'in between 2 trees', 'count': 1},
#  {'_id': 'By The Road', 'count': 1},
#  {'_id': 'on a fallen branch', 'count': 1},
#  {'_id': 'along dirt path by cross-town car road. saw movement in a shrub/then '
#          'caught sight a little fluffy tail',
#   'count': 1},
#  {'_id': 'tree hollow', 'count': 1},
#  {'_id': 'Ran across path to eat behind fence, next to the fence.', 'count': 1},
#  {'_id': 'to tree', 'count': 1},
#  {'_id': 'Large tree by (fence of the conservatory) about to climb up',
#   'count': 1},
#  {'_id': 'in tall shrubs near wall next to CPW', 'count': 1},
#  {'_id': 'In and below shrub', 'count': 2},
#  {'_id': 'ground & tree', 'count': 1},
#  {'_id': 'Under "Grape Arbor" structure behind Bandshell', 'count': 1},
#  {'_id': 'bottom of tree', 'count': 1},
#  {'_id': "high in tree, couldn't see it, only heard it", 'count': 1},
#  {'_id': 'Climbs small tree', 'count': 1},
#  {'_id': 'Between ground & tree', 'count': 1},
#  {'_id': 'Grassy area', 'count': 1},
#  {'_id': 'Shore', 'count': 3},
#  {'_id': 'Ran across path in front of people', 'count': 1},
#  {'_id': '', 'count': 2547},
#  {'_id': 'Crossing street', 'count': 1},
#  {'_id': 'in a tree', 'count': 3},
#  {'_id': 'Baseball field #3', 'count': 1},
#  {'_id': 'running across bridle path', 'count': 1},
#  {'_id': 'hopped over fence and chased # 6 around tree & ran it to end of lawn',
#   'count': 1},
#  {'_id': 'EDGE OF WOODS', 'count': 2},
#  {'_id': 'on rock (large)', 'count': 1},
#  {'_id': 'Running along stone ledge', 'count': 1},
#  {'_id': 'right at the base of the same tree as #3', 'count': 1},
#  {'_id': 'Branch', 'count': 1},
#  {'_id': 'crossing pavement in front of arsenal', 'count': 1},
#  {'_id': 'on trunk', 'count': 1},
#  {'_id': 'root bed of tree', 'count': 1},
#  {'_id': 'branch', 'count': 2},
#  {'_id': 'on lawn in front of a tree', 'count': 1},
#  {'_id': 'on a little pedestal-shaped part of a tree', 'count': 1},
#  {'_id': 'on top [of] a big rock/boulder in the area', 'count': 1},
#  {'_id': 'Undergrowth', 'count': 2},
#  {'_id': 'oak tree', 'count': 1},
#  {'_id': 'Climbing up tree', 'count': 1},
#  {'_id': 'treed area', 'count': 6},
#  {'_id': 'On trunk', 'count': 1},
#  {'_id': 'On the rock', 'count': 1},
#  {'_id': 'hanging out w/ Squirrel #1', 'count': 1},
#  {'_id': 'edge of the stream', 'count': 1},
#  {'_id': 'in tree by arsenal - climbing', 'count': 1},
#  {'_id': 'Running down tree', 'count': 1},
#  {'_id': 'on tree, blue jays gathering nearby', 'count': 1},
#  {'_id': 'branches', 'count': 2},
#  {'_id': 'By the main road', 'count': 1},
#  {'_id': 'on a rock', 'count': 2},
#  {'_id': 'Elm tree', 'count': 1},
#  {'_id': 'On low fence', 'count': 1},
#  {'_id': 'Crossing path', 'count': 1},
#  {'_id': 'running up tree', 'count': 1},
#  {'_id': 'along bottom of rock outcropping', 'count': 1},
#  {'_id': 'Behind fence, tree', 'count': 1},
#  {'_id': 'Bridle Path lawn', 'count': 2},
#  {'_id': 'in the playground.', 'count': 1},
#  {'_id': 'on turn, see map', 'count': 1},
#  {'_id': 'bush', 'count': 4},
#  {'_id': 'bottom great hill', 'count': 1},
#  {'_id': 'ran to tree', 'count': 1},
#  {'_id': 'in a tree with red berries', 'count': 1},
#  {'_id': 'up in tree', 'count': 1},
#  {'_id': 'Sitting on tree limb', 'count': 1},
#  {'_id': 'Between park and main drag', 'count': 1},
#  {'_id': 'in the bushes beneath a tree', 'count': 1},
#  {'_id': 'ran under dumpster w/ nut', 'count': 1},
#  {'_id': 'along the road', 'count': 3},
#  {'_id': 'tree & ground', 'count': 2},
#  {'_id': 'base of gingko tree', 'count': 1},
#  {'_id': 'bottom of great hill', 'count': 2},
#  {'_id': 'Moved 20+ feet high above top of tree limb', 'count': 1},
#  {'_id': 'Construction materials', 'count': 1},
#  {'_id': 'Flowers, grass', 'count': 1},
#  {'_id': 'By large tree', 'count': 1},
#  {'_id': 'on tree branch', 'count': 1},
#  {'_id': 'on stone arch', 'count': 1},
#  {'_id': 'edge of park @ 98th', 'count': 1},
#  {'_id': 'Rock', 'count': 4},
#  {'_id': 'Baseball field', 'count': 1},
#  {'_id': 'by rock', 'count': 1},
#  {'_id': 'Was on top of the edge of Bow Bridge', 'count': 1},
#  {'_id': 'in glen', 'count': 1},
#  {'_id': 'ran up a tree', 'count': 1},
#  {'_id': 'no clue, way up a tree!', 'count': 1},
#  {'_id': 'tree branches', 'count': 2},
#  {'_id': 'in grass by a grove of tall maples', 'count': 1},
#  {'_id': 'literally fell to ground from 50 feet up', 'count': 1},
#  {'_id': 'on ledge', 'count': 1},
#  {'_id': 'in tree!', 'count': 2},
#  {'_id': 'on top of tarped sand pile', 'count': 1},
#  {'_id': 'Fallen branch', 'count': 1},
#  {'_id': 'Big rock in meadow', 'count': 1},
#  {'_id': 'hiding in bushes', 'count': 1},
#  {'_id': 'on tree stump', 'count': 1},
#  {'_id': 'gingko tree by traffic light in front of Strawberry Fields',
#   'count': 1},
#  {'_id': 'running on rocks', 'count': 1},
#  {'_id': 'Jumped from ground onto branch', 'count': 1},
#  {'_id': 'A rock', 'count': 1},
#  {'_id': 'Pine tree near utility shed', 'count': 1},
#  {'_id': 'At fence', 'count': 1},
#  {'_id': 'ON ROCK NEAR POND', 'count': 1},
#  {'_id': 'Tree cavity [of] London Plane tree', 'count': 1},
#  {'_id': 'climbed tree', 'count': 2},
#  {'_id': 'under bushes', 'count': 3},
#  {'_id': 'Started in field, crossed busy street, ran up tree', 'count': 1},
#  {'_id': 'near 65th St arch', 'count': 1},
#  {'_id': 'lawn moving east over Park path', 'count': 1},
#  {'_id': 'Ground & Tree Base', 'count': 3},
#  {'_id': 'hanging upside down to get a nut', 'count': 1},
#  {'_id': 'LAWN', 'count': 1},
#  {'_id': '98th @ edge of park', 'count': 1},
#  {'_id': 'chasing from tree to ground', 'count': 2},
#  {'_id': 'elevated ground', 'count': 2},
#  {'_id': 'In tree', 'count': 3},
#  {'_id': 'Tree 90th left 90th & 89', 'count': 1},
#  {'_id': 'Trash bins', 'count': 1},
#  {'_id': 'top of tree', 'count': 2},
#  {'_id': 'Tree limb', 'count': 1},
#  {'_id': 'then perched on 2-ft high border fencing', 'count': 1},
#  {'_id': 'on tree facing downward', 'count': 1},
#  {'_id': 'large tree', 'count': 1},
#  {'_id': 'next to the hole of #6', 'count': 1},
#  {'_id': 'on tree roots', 'count': 1},
#  {'_id': 'Pond area', 'count': 1},
#  {'_id': 'by tree trunk base', 'count': 1},
#  {'_id': 'maple tree', 'count': 1},
#  {'_id': 'Oak tree', 'count': 1},
#  {'_id': 'Tree trunk', 'count': 1},
#  {'_id': 'on railing', 'count': 1},
#  {'_id': 'Gathering/digging in grassy area b/w trees', 'count': 1},
#  {'_id': 'up/down tree', 'count': 1},
#  {'_id': 'on a checker table', 'count': 1},
#  {'_id': 'tree top', 'count': 1},
#  {'_id': 'climbed up tree', 'count': 1}]

# %% [markdown]
# ## Add new latitude and longitude and round to 2 decimal places
